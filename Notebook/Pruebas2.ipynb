# %%
import pandas as pd
import re
from ../src.clean' import indice as ind
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 30)
# Out:
#   File "<ipython-input-208-a647b3514f74>", line 3
#     from '../src.clean' import indice as ind
#          ^
# SyntaxError: invalid syntax

# %%
#Abrimosel archivo para observar los datos que tenemos en el archivo attacks.csv
df_weather=pd.read_csv("../input/weather_features.csv",encoding='cp1252')
df_weather
# Out:
#                            dt_iso city_name     temp  temp_min  temp_max  \
# 0       2015-01-01 00:00:00+01:00  Valencia  270.475   270.475   270.475
# 1       2015-01-01 01:00:00+01:00  Valencia  270.475   270.475   270.475
# 2       2015-01-01 02:00:00+01:00  Valencia  269.686   269.686   269.686
# 3       2015-01-01 03:00:00+01:00  Valencia  269.686   269.686   269.686
# 4       2015-01-01 04:00:00+01:00  Valencia  269.686   269.686   269.686
# ...                           ...       ...      ...       ...       ...
# 178391  2018-12-31 19:00:00+01:00   Seville  287.760   287.150   288.150
# 178392  2018-12-31 20:00:00+01:00   Seville  285.760   285.150   286.150
# 178393  2018-12-31 21:00:00+01:00   Seville  285.150   285.150   285.150
# 178394  2018-12-31 22:00:00+01:00   Seville  284.150   284.150   284.150
# 178395  2018-12-31 23:00:00+01:00   Seville  283.970   282.150   285.150
#
#         pressure  humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  \
# ...

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178396 entries, 0 to 178395
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dt_iso               178396 non-null  object
#  1   city_name            178396 non-null  object
#  2   temp                 178396 non-null  float64
#  3   temp_min             178396 non-null  float64
#  4   temp_max             178396 non-null  float64
#  5   pressure             178396 non-null  int64
#  6   humidity             178396 non-null  int64
#  7   wind_speed           178396 non-null  int64
#  8   wind_deg             178396 non-null  int64
#  9   rain_1h              178396 non-null  float64
#  10  rain_3h              178396 non-null  float64
#  11  snow_3h              178396 non-null  float64
#  12  clouds_all           178396 non-null  int64
#  13  weather_id           178396 non-null  int64
#  14  weather_main         178396 non-null  object
# ...

# %%
df_weather['city_name'].unique()
# Out:
# array(['Valencia', 'Madrid', 'Bilbao', ' Barcelona', 'Seville'],
#       dtype=object)

# %%
cn.indice(df_weather['city_name'])



# x = df_weather['city_name']
# y=x.unique()
# count=0
# c=1
# indice=[]
# for i in x:
#     count +=1
#     if i == y[c]:
#         indice.append(x.index[count-1])
#         c+=1
#         if c == 5:
#             c=0
# indice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-32883ebd7741> in <module>
# ----> 1 cn.indice(df_weather['city_name'])
#       2
#       3
#       4
#       5 # x = df_weather['city_name']
#
# NameError: name 'cn' is not defined

# %%
df_weather[df_weather.index == 107362]
df_weather[df_weather.index == 107363]
# Out:
#                            dt_iso   city_name     temp  temp_min  temp_max  \
# 107363  2015-01-01 00:00:00+01:00   Barcelona  281.625   281.625   281.625
#
#         pressure  humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  \
# 107363      1035       100           7        58      0.0      0.0      0.0
#
#         clouds_all  weather_id weather_main weather_description weather_icon
# 107363           0         800        clear        sky is clear          01n

# %%
df_weather_valencia = df_weather[:35145].reset_index()
df_weather_madrid = df_weather[35145:71412].reset_index()
df_weather_bilbao = df_weather[71412:107363].reset_index()
df_weather_barcelona = df_weather[107363:142839].reset_index()
df_weather_sevilla = df_weather[142839:].reset_index()

# %%
df_weather_valencia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35145 entries, 0 to 35144
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                35145 non-null  int64
#  1   dt_iso               35145 non-null  object
#  2   city_name            35145 non-null  object
#  3   temp                 35145 non-null  float64
#  4   temp_min             35145 non-null  float64
#  5   temp_max             35145 non-null  float64
#  6   pressure             35145 non-null  int64
#  7   humidity             35145 non-null  int64
#  8   wind_speed           35145 non-null  int64
#  9   wind_deg             35145 non-null  int64
#  10  rain_1h              35145 non-null  float64
#  11  rain_3h              35145 non-null  float64
#  12  snow_3h              35145 non-null  float64
#  13  clouds_all           35145 non-null  int64
#  14  weather_id           35145 non-null  int64
# ...

# %%
df_weather_madrid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36267 entries, 0 to 36266
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                36267 non-null  int64
#  1   dt_iso               36267 non-null  object
#  2   city_name            36267 non-null  object
#  3   temp                 36267 non-null  float64
#  4   temp_min             36267 non-null  float64
#  5   temp_max             36267 non-null  float64
#  6   pressure             36267 non-null  int64
#  7   humidity             36267 non-null  int64
#  8   wind_speed           36267 non-null  int64
#  9   wind_deg             36267 non-null  int64
#  10  rain_1h              36267 non-null  float64
#  11  rain_3h              36267 non-null  float64
#  12  snow_3h              36267 non-null  float64
#  13  clouds_all           36267 non-null  int64
#  14  weather_id           36267 non-null  int64
# ...

# %%
24*365*4 == 35145
# Out:
# False

# %%
24*365*3+(24*366) == 35145
# Out:
# False

# %%
df_weather_valencia2=df_weather_valencia.drop_duplicates(subset=['dt_iso'], keep='last')
df_weather_madrid2=df_weather_madrid.drop_duplicates(subset=['dt_iso'], keep='last')
df_weather_bilbao2=df_weather_bilbao.drop_duplicates(subset=['dt_iso'], keep='last')
df_weather_barcelona2=df_weather_barcelona.drop_duplicates(subset=['dt_iso'], keep='last')
df_weather_sevilla2=df_weather_sevilla.drop_duplicates(subset=['dt_iso'], keep='last')

# %%
len(df_weather_valencia2.index) == len(df_weather_madrid2.index) == len(df_weather_bilbao2.index) == len(df_weather_barcelona2.index) == len(df_weather_sevilla2.index)
# Out:
# True

# %%
len(df_weather_valencia2.index) == 24*365*3+(24*366)
# Out:
# True

# %%
#con los datos que voy a trabajar

#temp(K)	temp_min(K)	temp_max(K)	pressure(hPa) humidity(%) wind_speed(m/s)
# Out:
# True

# %%
#Abrimosel archivo para observar los datos que tenemos en el archivo attacks.csv
#lista de dias meses
#['31', '28', '30', '31', '30', '31', '30', '31', '30', '31', '30', '31']
temps=0
x=0
new=[]
for i in df_weather_valencia2['temp']:
    temps += i
    x += 1
    if x == 24:
        new.append(temps/24)
        x=0
        temps=0
print(len(new))
new
# Out:
# 1461
# [275.9555703125,
#  276.7388333333333,
#  279.0440104166667,
#  279.36666666666673,
#  278.7405208333334,
#  278.10953515625005,
#  280.368890625,
#  280.7863750000001,
#  281.60479557291677,
#  286.9811315104167,
#  286.55693098958335,
#  282.97916666666674,
#  284.6708333333334,
#  286.18333333333334,
#  285.5436601562501,
#  284.5834869791667,
#  281.27916666666664,
#  279.99375,
#  279.1217278645833,
#  277.94166666666666,
#  279.23120703125005,
#  280.68879166666665,
#  281.4128958333333,
#  281.18822265625005,
#  284.22493749999995,
#  280.2894999999999,
#  282.31252083333334,
#  281.9505377604167,
#  283.7867460937501,
#  289.1081744791667,
#  284.7208125,
#  280.3358125,
#  280.48789583333337,
#  282.58867838541664,
#  278.81250000000006,
#  278.57656249999997,
#  277.54621484374996,
#  276.2583333333334,
#  277.9331041666666,
#  278.558375,
#  281.01875,
#  281.4811458333333,
#  281.34583333333336,
#  283.89254166666666,
#  285.55833333333334,
#  287.2969817708333,
# ...

# %%
#funcion para sacar el promedio mensual desde el año 2015 hasta el 2018 de las 5 provincias
mes=['31', '28', '30', '31', '30', '31', '30', '31', '30', '31', '30', '31']
mes2= ['31', '29', '30', '31', '30', '31', '30', '31', '30', '31', '30', '31']
new2=[]
m=0
x=0
c=0
y=1
u=0
for i in new:
    if y!=2:
        m += i
        x +=1
        if str(x) == mes[c]:
            f=mes[c]
            f=int(f)
            new2.append(m/f)
            c+=1
            x=0
            m=0
            if c > 11:
                c=0           
                u += 1
                if u == 1:
                    y=2   
    else:
        m += i
        x +=1
        if str(x) == mes2[c]:
            f=mes2[c]
            f=int(f)
            new2.append(m/f)
            c+=1
            x=0
            m=0
            if c > 11:
                c=0
                y=1
                u+=1
                   
print(len(new2))
print(new2)
# Out:
# 48
# [281.78917414314515, 282.67181236049106, 284.87533867187506, 287.07098202284953, 292.1168371527777, 295.4278642473118, 300.2297916666667, 298.4777419354839, 294.4939430555556, 291.09854502688177, 287.8050373263888, 284.1184698840726, 285.07872605846774, 285.7279398796696, 285.85852313368054, 288.96055817372314, 290.644417361111, 295.37432325268816, 297.74560972222224, 298.3341552419355, 295.7310567274306, 290.60608849966394, 287.0604752604166, 284.87043014952945, 282.27476881720423, 284.66302087983615, 287.1864236111111, 288.518965095766, 293.0451416666665, 298.23265322580636, 299.67021610243046, 299.9944254032257, 296.19972322048596, 293.6999321236558, 287.39488263888876, 283.3515376344086, 285.6039274193548, 283.08728571428566, 286.25951840277764, 289.5301021505375, 292.06027361111103, 296.3158991935483, 300.22662222222215, 300.78546874999984, 298.2238784722221, 292.80456989247295, 287.0493340277777, 284.8215456989248]
